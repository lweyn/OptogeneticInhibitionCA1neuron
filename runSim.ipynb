# %%
from Functions.setup import simParams
from Functions.utils import Dict
from Functions.Simulation import runSimulation
from Functions.plots import plotResults
import warnings; warnings.simplefilter('ignore')
# %matplotlib inline

for opsin in ['Cl22OM', 'K22OM', 'Cl22OMs', 'K22OMs']:
    input = Dict(simParams().todict(inplace=False))
    input.cellsopt.opsin_options.opsinmech = opsin
    results = runSimulation(input)
    plotResults(input, results)
